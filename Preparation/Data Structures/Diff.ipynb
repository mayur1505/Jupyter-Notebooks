# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sets, dictionaries, tuples, and lists are all different data structures in Python, each with its own characteristics and use cases. Here's a brief overview of their differences:
#
# **1> Lists:**
#
# Lists are ordered collections of items.
#
# They are mutable, meaning you can change, add, or remove elements after the list is created.
#
# Lists are defined using square brackets [ ].
#
# Lists allow duplicate elements.
#
# Lists are typically used when you need a collection of items that can be modified or reordered.
#
# **2> Tuples:**
#
# Tuples are ordered collections of items, similar to lists.
#
# However, tuples are immutable, meaning once created, their elements cannot be changed.
#
# Tuples are defined using parentheses ().
#
# Tuples are usually used for storing collections of items that shouldn't change, such as coordinates, database records, or function return values.
#
# **3> Sets:**
#
# Sets are unordered collections of unique elements.
#
# They do not allow duplicate elements.
#
# Sets are mutable, meaning you can add or remove elements after the set is created.
#
# Sets are defined using curly braces { } or the set() constructor.
#
# Sets are often used for tasks involving mathematical operations like union, intersection, and difference, or for removing duplicates from a collection.
#
# **4> Dictionaries:**
#
# Dictionaries are collections of key-value pairs.
# They are unordered and mutable.
#
# Each key in a dictionary must be unique.
#
# Dictionaries are defined using curly braces { }, with key-value pairs separated by colons : (e.g., {'name': 'John', 'age': 30}) or using the dict() constructor.
#
# Dictionaries are commonly used for storing data that needs to be looked up quickly based on a key, such as user information, configuration settings, or mapping relationships between items.m
