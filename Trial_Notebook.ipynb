# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\HP\\Desktop\\Internship\\employees.csv")

# %%
df
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management     67
# Team                  43
# dtype: int64

# %%
df.sort_values("First Name", inplace = True)

# %%
df
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male  2/17/2012        10:20 AM   61602   11.849
# 327      Aaron    Male  1/29/1994         6:48 PM   58755    5.097
# 440      Aaron    Male  7/22/1990         2:53 PM   52119   11.343
# 937      Aaron     NaN  1/22/1986         7:39 PM   63126   18.424
# 137       Adam    Male  5/21/2011         1:45 AM   95327   15.120
# ..         ...     ...        ...             ...     ...      ...
# 902        NaN    Male  5/23/2001         7:52 PM  103877    6.322
# 925        NaN  Female  8/23/2000         4:19 PM   95866   19.388
# 946        NaN  Female  9/15/1985         1:50 AM  133472   16.941
# 947        NaN    Male  7/30/2012         3:07 PM  107351    5.329
# 951        NaN  Female  9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management             Team
# 101              True        Marketing
# 327              True        Marketing
# 440              True  Client Services
# ...

# %%
df.head(20)
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male   2/17/2012        10:20 AM   61602   11.849
# 327      Aaron    Male   1/29/1994         6:48 PM   58755    5.097
# 440      Aaron    Male   7/22/1990         2:53 PM   52119   11.343
# 937      Aaron     NaN   1/22/1986         7:39 PM   63126   18.424
# 137       Adam    Male   5/21/2011         1:45 AM   95327   15.120
# 141       Adam    Male  12/24/1990         8:57 PM  110194   14.727
# 302       Adam    Male    7/5/2007        11:59 AM   71276    5.027
# 538       Adam    Male   10/8/2010         9:53 PM   45181    3.491
# 300       Alan    Male   6/26/1988         3:54 AM  111786    3.592
# 53        Alan     NaN    3/3/2014         1:28 PM   40341   17.578
# 610       Alan    Male   2/17/2012        12:26 AM   41453   10.084
# 372     Albert    Male    2/1/1997         4:20 PM   67827   19.717
# 458     Albert    Male   9/30/2007         5:34 PM  102626   15.843
# ...

# %%
bool_series = df["First Name"].duplicated()# making a bool seriesdata[bool_series]

# %%
bool_series
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# 137    False
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951     True
# Name: First Name, Length: 1000, dtype: bool

# %%
df[~bool_series]#showing unique and first unique values by removing duplicates
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male   2/17/2012        10:20 AM   61602   11.849
# 137       Adam    Male   5/21/2011         1:45 AM   95327   15.120
# 300       Alan    Male   6/26/1988         3:54 AM  111786    3.592
# 372     Albert    Male    2/1/1997         4:20 PM   67827   19.717
# 988      Alice  Female   10/5/2004         9:34 AM   47638   11.209
# ..         ...     ...         ...             ...     ...      ...
# 433      Wanda  Female   7/20/2008         1:44 PM   65362    7.132
# 177      Wayne    Male    4/7/2012         8:00 AM  102652   14.085
# 820    William    Male  11/18/1993        12:27 PM   54058    5.182
# 450     Willie    Male   8/22/2009         1:03 PM   55038   19.691
# 7          NaN  Female   7/20/2015        10:43 AM   45906   11.598
#
#     Senior Management             Team
# 101              True        Marketing
# 137             False     Distribution
# ...

# %%
df1=pd.read_csv("C:\\Users\\HP\\Desktop\\Internship\\employees.csv")

# %%
df1.shape
# Out:
# (1000, 8)

# %%
df1.sort_values("First Name", inplace = True)

# %%
series=df1.duplicated()

# %%
df[~series]
# Out:
#     First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male  2/17/2012        10:20 AM   61602   11.849
# 327      Aaron    Male  1/29/1994         6:48 PM   58755    5.097
# 440      Aaron    Male  7/22/1990         2:53 PM   52119   11.343
# 937      Aaron     NaN  1/22/1986         7:39 PM   63126   18.424
# 137       Adam    Male  5/21/2011         1:45 AM   95327   15.120
# ..         ...     ...        ...             ...     ...      ...
# 902        NaN    Male  5/23/2001         7:52 PM  103877    6.322
# 925        NaN  Female  8/23/2000         4:19 PM   95866   19.388
# 946        NaN  Female  9/15/1985         1:50 AM  133472   16.941
# 947        NaN    Male  7/30/2012         3:07 PM  107351    5.329
# 951        NaN  Female  9/14/2010         5:19 AM  143638    9.662
#
#     Senior Management             Team
# 101              True        Marketing
# 327              True        Marketing
# 440              True  Client Services
# ...

# %% [raw]
# In df we remove duplicates on the basis of first name, i.e. if the first name is same then only keep the first row and remove other rows with same name.
# But in df1 we did not specify column , we checked for entire row i.e entire row should be same but there are no such duplicates.
